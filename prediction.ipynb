# %% [markdown]
# # **INF161 - Bike Traffic Predictions**
# ### *Ole Kristian Westby | owe009@uib.no | H23*
#
# In this notebook, with our model now ready, and our data ready to predict with. We will do one of the last things of the assignment, which is to take the model, 2023 data and predict how many cycle each hour for the entirety of 2023.

# %%
import pandas as pd
import numpy as np

dir = "predictions/Florida_2023-01-01_2023-07-01_1688719120.csv"
out = "predictions/predictions.csv"

df = pd.read_csv(dir)

df['Datotid'] = pd.to_datetime(df['Dato'] + ' ' + df['Tid'])
df.drop(['Dato', 'Tid'], axis=1, inplace=True)

df.head()
# Out:
#    Globalstraling  Solskinstid  Lufttemperatur  Relativ luftfuktighet  \
# 0            -3.6          0.0            -0.2                   83.0
# 1            -3.1          0.0             0.1                   84.0
# 2            -2.6          0.0             0.9                   79.0
# 3            -2.7          0.0             1.1                   70.0
# 4            -2.6          0.0             1.2                   67.0
#
#    Vindretning  Vindstyrke  Lufttrykk  Vindkast             Datotid
# 0        20.00         0.1      994.6       0.6 2023-01-01 00:00:00
# 1      9999.99         0.3      994.8       1.2 2023-01-01 00:10:00
# 2        44.00         1.6      994.8       3.6 2023-01-01 00:20:00
# 3        58.00         1.9      994.8       3.9 2023-01-01 00:30:00
# 4        48.00         1.6      995.0       2.7 2023-01-01 00:40:00

# %%
missing_indicator = 9999.99
df.replace(missing_indicator, np.nan, inplace=True)

df.head()
# Out:
#    Globalstraling  Solskinstid  Lufttemperatur  Relativ luftfuktighet  \
# 0            -3.6          0.0            -0.2                   83.0
# 1            -3.1          0.0             0.1                   84.0
# 2            -2.6          0.0             0.9                   79.0
# 3            -2.7          0.0             1.1                   70.0
# 4            -2.6          0.0             1.2                   67.0
#
#    Vindretning  Vindstyrke  Lufttrykk  Vindkast             Datotid
# 0         20.0         0.1      994.6       0.6 2023-01-01 00:00:00
# 1          NaN         0.3      994.8       1.2 2023-01-01 00:10:00
# 2         44.0         1.6      994.8       3.6 2023-01-01 00:20:00
# 3         58.0         1.9      994.8       3.9 2023-01-01 00:30:00
# 4         48.0         1.6      995.0       2.7 2023-01-01 00:40:00

# %%
for col in df.columns:
    df[col].fillna(df[col].median(), inplace=True)

df.head()
# Out:
#    Globalstraling  Solskinstid  Lufttemperatur  Relativ luftfuktighet  \
# 0            -3.6          0.0            -0.2                   83.0
# 1            -3.1          0.0             0.1                   84.0
# 2            -2.6          0.0             0.9                   79.0
# 3            -2.7          0.0             1.1                   70.0
# 4            -2.6          0.0             1.2                   67.0
#
#    Vindretning  Vindstyrke  Lufttrykk  Vindkast             Datotid
# 0         20.0         0.1      994.6       0.6 2023-01-01 00:00:00
# 1        164.0         0.3      994.8       1.2 2023-01-01 00:10:00
# 2         44.0         1.6      994.8       3.6 2023-01-01 00:20:00
# 3         58.0         1.9      994.8       3.9 2023-01-01 00:30:00
# 4         48.0         1.6      995.0       2.7 2023-01-01 00:40:00

# %%
# Columns we will feed into model for predictions
interesting_cols = ['Datotid', 'Globalstraling', 'Solskinstid', 'Lufttemperatur', 'Vindstyrke', 'Vindkast']

X_predict = df[interesting_cols]

X_predict['Month'] = X_predict['Datotid'].dt.month
X_predict['DayOfWeek'] = X_predict['Datotid'].dt.dayofweek
X_predict['Hour'] = X_predict['Datotid'].dt.hour
X_predict['Minute'] = X_predict['Datotid'].dt.minute
# Out:
# C:\Users\owe05\AppData\Local\Temp\ipykernel_484\644488175.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_predict['Month'] = X_predict['Datotid'].dt.month
# C:\Users\owe05\AppData\Local\Temp\ipykernel_484\644488175.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_predict['DayOfWeek'] = X_predict['Datotid'].dt.dayofweek

# %%
from model import rf

predicted_traffic = rf.predict(X_predict)
df['PREDICTED Trafikkmengde'] = predicted_traffic

df.head()
